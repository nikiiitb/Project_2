# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from transformers import AutoModel , AutoImageProcessor , AutoTokenizer 
from datasets import load_dataset , Dataset
from datasets import Image as dImage
from PIL import Image
import torch
from torch import nn
from sklearn.model_selection import train_test_split
import pickle

torch.cuda.empty_cache()

# import os
# os.environ['TF_GPU_ALLOCATOR']='cuda_malloc_async'

# %%
# SAMPLES = 100
# df_acc = pd.read_pickle("./vqa_v2_acc.pkl")
# df = df_acc[:SAMPLES]

SAMPLE_SET = "100k"
# SAMPLE_SET = "10k"

df = pd.read_pickle(f"vqa_v2_sampled_{SAMPLE_SET}_clipped.pkl")
SAMPLES = len(df)

print("Number of samples are : " , SAMPLES)

df.head()
# Out:
# Number of samples are :  143000
#                                             question question_type  \
# 0  Are all people in the image facing the same di...           are
# 1           Are people getting on and off the train?           are
# 2                    Are any people in this picture?           are
# 3                            Are those pizza slices?           are
# 4                        Are people on the ski lift?           are
#
#    question_id                         image_id answer_type  \
# 0    107156001  COCO_train2014_000000107156.jpg      yes/no
# 1    285042000  COCO_train2014_000000285042.jpg      yes/no
# 2    506653001  COCO_train2014_000000506653.jpg      yes/no
# 3    464340001  COCO_train2014_000000464340.jpg      yes/no
# 4    490267000  COCO_train2014_000000490267.jpg      yes/no
#
#                                           label
# 0  {'ids': ['yes', '2'], 'weights': [0.9, 0.1]}
# 1             {'ids': ['no'], 'weights': [1.0]}
# 2            {'ids': ['yes'], 'weights': [1.0]}
# 3             {'ids': ['no'], 'weights': [1.0]}
# 4            {'ids': ['yes'], 'weights': [1.0]}

# %%
np.array(Image.open("./train2014_3d/" + df["image_id"][0])).shape
# Out:
# (426, 640, 3)

# %%
Image.open("./train2014_3d/" + df["image_id"][0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426>

# %% [markdown]
# Creating Labels

# %%
label2id = pickle.load(open(f"label2id_{SAMPLE_SET}_clipped.pkl" , "rb"))
id2label = pickle.load(open(f"id2label_{SAMPLE_SET}_clipped.pkl" , "rb"))

# %%
label2id
# Out:
# {'spinach': 0,
#  'inside': 1,
#  'stick': 2,
#  'lemon': 3,
#  'blue and white': 4,
#  'olives': 5,
#  'clay': 6,
#  'tennis racquet': 7,
#  'standing': 8,
#  'tulips': 9,
#  '32': 10,
#  'beanie': 11,
#  'christmas': 12,
#  'work': 13,
#  'dark brown': 14,
#  'wine': 15,
#  'cloth': 16,
#  'green and blue': 17,
#  'blue, white': 18,
#  'orange and white': 19,
#  'dark': 20,
#  'shadow': 21,
#  'living': 22,
#  '21': 23,
#  'field': 24,
#  'phone': 25,
#  'coke': 26,
#  'tiles': 27,
#  '36': 28,
#  'scarf': 29,
#  'too many to count': 30,
#  '23': 31,
#  'skateboarding': 32,
#  'evening': 33,
#  'boy': 34,
#  'playing tennis': 35,
#  'modern': 36,
#  'trash can': 37,
#  '2': 38,
#  'north': 39,
#  'uk': 40,
#  'diamond': 41,
#  'dirty': 42,
#  'burgundy': 43,
#  'right': 44,
#  '17': 45,
#  'rectangular': 46,
#  'flying': 47,
#  'autumn': 48,
#  'string': 49,
#  'hair': 50,
#  'kites': 51,
#  'weeds': 52,
#  'khaki': 53,
#  '5': 54,
#  'to left': 55,
#  'africa': 56,
#  'posing': 57,
#  'up': 58,
#  'afternoon': 59,
#  'hydrant': 60,
#  'tile': 61,
#  'on desk': 62,
#  'black and gray': 63,
#  'tree': 64,
#  'playing': 65,
#  'person': 66,
#  'bridge': 67,
#  'carrots': 68,
#  'graffiti': 69,
#  'vinyl': 70,
#  'white and yellow': 71,
#  'game': 72,
#  'parked': 73,
#  'middle': 74,
#  'wires': 75,
#  'tan': 76,
#  'couch': 77,
#  'restroom': 78,
#  'floral': 79,
#  'riding': 80,
#  'west': 81,
#  'not visible': 82,
#  'hands': 83,
#  'road': 84,
#  'outdoors': 85,
#  '35': 86,
#  '30': 87,
#  'skateboarder': 88,
#  'remote': 89,
#  'nowhere': 90,
#  'outside': 91,
#  'silver': 92,
#  'country': 93,
#  'sitting': 94,
#  'tabby': 95,
#  'scissors': 96,
#  'soccer ball': 97,
#  'leather': 98,
#  'fair': 99,
#  'signs': 100,
#  'mustard': 101,
#  '60': 102,
#  'pine': 103,
#  'milk': 104,
#  'straw': 105,
#  'transportation': 106,
#  'taking off': 107,
#  'suitcase': 108,
#  'red and green': 109,
#  'playing frisbee': 110,
#  'sandwiches': 111,
#  'design': 112,
#  'soccer': 113,
#  'passenger': 114,
#  'brown and black': 115,
#  'kitchen': 116,
#  'above': 117,
#  'not here': 118,
#  'motorcycles': 119,
#  'white and blue': 120,
#  'toothbrush': 121,
#  'staring': 122,
#  'subway': 123,
#  'night': 124,
#  'racket': 125,
#  'reflection': 126,
#  'house': 127,
#  'parking lot': 128,
#  'ski poles': 129,
#  'frosting': 130,
#  'asphalt': 131,
#  'wave': 132,
#  'restaurant': 133,
#  'cutting board': 134,
#  'granite': 135,
#  'turkey': 136,
#  'tennis': 137,
#  'down': 138,
#  'donut': 139,
#  'purple': 140,
#  '7': 141,
#  'curtains': 142,
#  'looking': 143,
#  'animal': 144,
#  'working': 145,
#  'station': 146,
#  'fake': 147,
#  'london': 148,
#  'potato': 149,
#  'closed': 150,
#  '18': 151,
#  'umbrella': 152,
#  'table': 153,
#  'pink and white': 154,
#  'drinking': 155,
#  'yellow and green': 156,
#  'plane': 157,
#  'ceiling': 158,
#  'tray': 159,
#  'jet': 160,
#  '12': 161,
#  'fork': 162,
#  '1000': 163,
#  'in background': 164,
#  'cake': 165,
#  'traffic': 166,
#  'red white and blue': 167,
#  '70': 168,
#  'ham': 169,
#  'aqua': 170,
#  'bear': 171,
#  'rain': 172,
#  'new': 173,
#  'farm': 174,
#  '5 feet': 175,
#  'camera': 176,
#  'steam': 177,
#  'usa': 178,
#  '55': 179,
#  'wind': 180,
#  'linoleum': 181,
#  'logo': 182,
#  'hot dog': 183,
#  'daisies': 184,
#  'luggage': 185,
#  'hay': 186,
#  'bracelet': 187,
#  'leaves': 188,
#  'helmet': 189,
#  '80': 190,
#  'gloves': 191,
#  'african': 192,
#  'blue': 193,
#  'soda': 194,
#  'light brown': 195,
#  "i don't know": 196,
#  'turquoise': 197,
#  'batting': 198,
#  'right hand': 199,
#  'spring': 200,
#  '200': 201,
#  'surf': 202,
#  'indoors': 203,
#  'bags': 204,
#  'dirt': 205,
#  'tower': 206,
#  'buildings': 207,
#  'bathroom': 208,
#  'collie': 209,
#  'sleeping': 210,
#  "can't tell": 211,
#  'rainbow': 212,
#  'laying': 213,
#  'labrador': 214,
#  'red and blue': 215,
#  'open': 216,
#  'cows': 217,
#  'dusk': 218,
#  'umpire': 219,
#  'white and brown': 220,
#  'playing video games': 221,
#  'united states': 222,
#  'asia': 223,
#  'green and yellow': 224,
#  'baseball bat': 225,
#  'toy': 226,
#  'in air': 227,
#  'skiing': 228,
#  'school': 229,
#  'clothes': 230,
#  'long': 231,
#  'airplane': 232,
#  'basket': 233,
#  'beans': 234,
#  'goat': 235,
#  'sauce': 236,
#  'ponytail': 237,
#  'mac': 238,
#  'aluminum': 239,
#  'wire': 240,
#  'unsure': 241,
#  'skateboard': 242,
#  'drink': 243,
#  'europe': 244,
#  'downtown': 245,
#  'paper': 246,
#  'pizza': 247,
#  'left one': 248,
#  'post': 249,
#  'dress': 250,
#  'triangle': 251,
#  'germany': 252,
#  'hot': 253,
#  'winter': 254,
#  'marble': 255,
#  'shorts': 256,
#  'off white': 257,
#  'beer': 258,
#  'medium': 259,
#  'kids': 260,
#  'burger': 261,
#  'paint': 262,
#  'mouse': 263,
#  'sony': 264,
#  'cow': 265,
#  '19': 266,
#  '42': 267,
#  'surfing': 268,
#  'waiting': 269,
#  'rope': 270,
#  'lady': 271,
#  'rose': 272,
#  'planes': 273,
#  'pork': 274,
#  '14': 275,
#  'candle': 276,
#  'bush': 277,
#  'towel': 278,
#  'stairs': 279,
#  'dessert': 280,
#  'snow': 281,
#  'sail': 282,
#  'sign': 283,
#  'watch': 284,
#  'book': 285,
#  'suv': 286,
#  'friend': 287,
#  'trash': 288,
#  'duck': 289,
#  'animals': 290,
#  'snowboard': 291,
#  '100': 292,
#  'laying down': 293,
#  'curtain': 294,
#  'squares': 295,
#  'man': 296,
#  'small': 297,
#  'red, white': 298,
#  'cotton': 299,
#  'on road': 300,
#  '10 feet': 301,
#  'all of them': 302,
#  'jacket': 303,
#  'ducks': 304,
#  'left side': 305,
#  'ski': 306,
#  'police': 307,
#  'military': 308,
#  'people': 309,
#  'lamp': 310,
#  'in front': 311,
#  'in water': 312,
#  'blue and green': 313,
#  'hundreds': 314,
#  'fan': 315,
#  'laptop': 316,
#  'france': 317,
#  'counter': 318,
#  'brown': 319,
#  'building': 320,
#  'right one': 321,
#  'sandals': 322,
#  'on left': 323,
#  'maybe': 324,
#  'away': 325,
#  'wood': 326,
#  'lines': 327,
#  'mirror': 328,
#  'den': 329,
#  'flying kite': 330,
#  'apple': 331,
#  'sweater': 332,
#  'china': 333,
#  'dog': 334,
#  'birds': 335,
#  'bar': 336,
#  'boots': 337,
#  'egg': 338,
#  'letters': 339,
#  'purse': 340,
#  'birthday cake': 341,
#  'water skiing': 342,
#  'wii remote': 343,
#  'downhill': 344,
#  'low': 345,
#  'candy': 346,
#  'racing': 347,
#  'truck': 348,
#  'cheese': 349,
#  'rack': 350,
#  'us': 351,
#  '27': 352,
#  'screen': 353,
#  'sheep': 354,
#  'sunset': 355,
#  '?': 356,
#  'calm': 357,
#  'front': 358,
#  'protection': 359,
#  'delta': 360,
#  'sun': 361,
#  'red white': 362,
#  'coca cola': 363,
#  'harley': 364,
#  'black and silver': 365,
#  'apartment': 366,
#  "don't know": 367,
#  'women': 368,
#  'birthday': 369,
#  'office': 370,
#  'rocks': 371,
#  'california': 372,
#  'playing wii': 373,
#  'chicken': 374,
#  'round': 375,
#  'side': 376,
#  'white and black': 377,
#  'blue and yellow': 378,
#  'cat': 379,
#  'living room': 380,
#  'box': 381,
#  'human': 382,
#  'poles': 383,
#  'nike': 384,
#  'green and black': 385,
#  'several': 386,
#  'no idea': 387,
#  'blanket': 388,
#  'breakfast': 389,
#  'town': 390,
#  'smile': 391,
#  'good': 392,
#  'yellow and white': 393,
#  'gaming': 394,
#  'neither': 395,
#  'flying kites': 396,
#  'heart': 397,
#  'not possible': 398,
#  'banana': 399,
#  'cars': 400,
#  'lettuce': 401,
#  'dining': 402,
#  'bushes': 403,
#  'racquet': 404,
#  'no one': 405,
#  'n': 406,
#  'potatoes': 407,
#  'japanese': 408,
#  'wetsuit': 409,
#  'family': 410,
#  'young': 411,
#  'windows': 412,
#  'goats': 413,
#  'center': 414,
#  'sofa': 415,
#  'circular': 416,
#  'palm trees': 417,
#  'on ground': 418,
#  'cold': 419,
#  'lake': 420,
#  'in back': 421,
#  'hill': 422,
#  'carriage': 423,
#  'yellow': 424,
#  'not very': 425,
#  'pillow': 426,
#  '75': 427,
#  'smoke': 428,
#  'hills': 429,
#  'talking on phone': 430,
#  'napkin': 431,
#  'toilet': 432,
#  'stone': 433,
#  'boston': 434,
#  'ocean': 435,
#  'horse': 436,
#  '24': 437,
#  'vanilla': 438,
#  'italian': 439,
#  'decoration': 440,
#  'yellow and red': 441,
#  'honda': 442,
#  'out': 443,
#  'art': 444,
#  'one on left': 445,
#  'cooking': 446,
#  'none': 447,
#  'red': 448,
#  'britain': 449,
#  'mountains': 450,
#  'toyota': 451,
#  'television': 452,
#  'oranges': 453,
#  'green': 454,
#  'sunny': 455,
#  'on bed': 456,
#  'city': 457,
#  'shoes': 458,
#  'high': 459,
#  'roof': 460,
#  'green and brown': 461,
#  'bat': 462,
#  'shirt': 463,
#  '6 feet': 464,
#  'eating': 465,
#  'giraffe': 466,
#  'bears': 467,
#  'mountain': 468,
#  'black and white': 469,
#  'collar': 470,
#  'bread': 471,
#  '0': 472,
#  'jump': 473,
#  'dark blue': 474,
#  'east': 475,
#  'soup': 476,
#  'mitt': 477,
#  'cement': 478,
#  'glove': 479,
#  'texting': 480,
#  'chocolate': 481,
#  'pants': 482,
#  'stuffed animal': 483,
#  'vase': 484,
#  'sunglasses': 485,
#  'red and black': 486,
#  'one on right': 487,
#  'white': 488,
#  'glasses': 489,
#  'motorcycle': 490,
#  'tv': 491,
#  'square': 492,
#  'men': 493,
#  'crane': 494,
#  'striped': 495,
#  'terrier': 496,
#  'left': 497,
#  'steel': 498,
#  'asian': 499,
#  'cell phone': 500,
#  'ford': 501,
#  'walking': 502,
#  '28': 503,
#  'woods': 504,
#  'in middle': 505,
#  '29': 506,
#  'baby': 507,
#  'forest': 508,
#  'male': 509,
#  'land': 510,
#  'porcelain': 511,
#  'pasta': 512,
#  'lamb': 513,
#  'daisy': 514,
#  'trees': 515,
#  'zoo': 516,
#  'landing': 517,
#  'stand': 518,
#  'oval': 519,
#  'gravel': 520,
#  'taking picture': 521,
#  'runway': 522,
#  'park': 523,
#  'clock tower': 524,
#  'adidas': 525,
#  'vegetables': 526,
#  'frisbee': 527,
#  'talking': 528,
#  'pavement': 529,
#  'ball': 530,
#  'maple': 531,
#  'parsley': 532,
#  'boats': 533,
#  'remote control': 534,
#  'umbrellas': 535,
#  'catcher': 536,
#  'evergreen': 537,
#  'spanish': 538,
#  'clear': 539,
#  'on floor': 540,
#  'black and blue': 541,
#  'beach': 542,
#  'juice': 543,
#  'teal': 544,
#  'pelican': 545,
#  'rock': 546,
#  'overcast': 547,
#  'light blue': 548,
#  '26': 549,
#  'oven': 550,
#  'party': 551,
#  'chicago': 552,
#  'doughnuts': 553,
#  'rug': 554,
#  'black, white': 555,
#  "can't see": 556,
#  '38': 557,
#  'stainless steel': 558,
#  '13': 559,
#  'clock': 560,
#  'cloudy': 561,
#  'on street': 562,
#  'elephants': 563,
#  'air': 564,
#  'fruits': 565,
#  'fries': 566,
#  'onion': 567,
#  'lots': 568,
#  'river': 569,
#  'in field': 570,
#  'noon': 571,
#  'cannot tell': 572,
#  'handle': 573,
#  'family room': 574,
#  'night time': 575,
#  'desert': 576,
#  'sunlight': 577,
#  'fruit': 578,
#  'black white': 579,
#  'off': 580,
#  'light': 581,
#  '3 feet': 582,
#  'american': 583,
#  'train': 584,
#  'carpet': 585,
#  'bottle': 586,
#  'flowers': 587,
#  'painting': 588,
#  'to right': 589,
#  'white and green': 590,
#  'rainy': 591,
#  'onions': 592,
#  'pan': 593,
#  'brown and white': 594,
#  'circle': 595,
#  'tomatoes': 596,
#  'church': 597,
#  'pitcher': 598,
#  'donuts': 599,
#  'parking': 600,
#  '300': 601,
#  'seagull': 602,
#  'concrete': 603,
#  'green and red': 604,
#  'swimming': 605,
#  'red and white': 606,
#  'raining': 607,
#  'electricity': 608,
#  'cap': 609,
#  'white and orange': 610,
#  'maroon': 611,
#  'dock': 612,
#  'white and gray': 613,
#  'hat': 614,
#  'door': 615,
#  'scooter': 616,
#  '15': 617,
#  '20': 618,
#  'driving': 619,
#  'possibly': 620,
#  'multicolored': 621,
#  '22': 622,
#  'ceramic': 623,
#  'na': 624,
#  'blue and gray': 625,
#  'fish': 626,
#  'warm': 627,
#  'dozens': 628,
#  'stop sign': 629,
#  'clean': 630,
#  'solid': 631,
#  'wedding': 632,
#  'lot': 633,
#  'jumping': 634,
#  'right side': 635,
#  'color': 636,
#  'outdoor': 637,
#  'veggies': 638,
#  'lab': 639,
#  'stripe': 640,
#  'sink': 641,
#  'orange and black': 642,
#  '50': 643,
#  'big': 644,
#  'watching': 645,
#  'electric': 646,
#  'playing game': 647,
#  'background': 648,
#  'video game': 649,
#  'both': 650,
#  'on table': 651,
#  '6': 652,
#  'multi': 653,
#  'rectangle': 654,
#  'on right': 655,
#  'gold': 656,
#  'beef': 657,
#  'safety': 658,
#  'picture': 659,
#  'black & white': 660,
#  '2 feet': 661,
#  'chair': 662,
#  'lights': 663,
#  'batter': 664,
#  'plant': 665,
#  'black/white': 666,
#  'fridge': 667,
#  'track': 668,
#  'no number': 669,
#  'fabric': 670,
#  'wild': 671,
#  'bicycle': 672,
#  'flower': 673,
#  'red and yellow': 674,
#  'surfboarding': 675,
#  '4': 676,
#  'photographer': 677,
#  'hand': 678,
#  'italy': 679,
#  'bacon': 680,
#  'necklace': 681,
#  'steak': 682,
#  'black and red': 683,
#  'relaxing': 684,
#  'zebras': 685,
#  'cattle': 686,
#  'unclear': 687,
#  'street': 688,
#  't-shirt': 689,
#  'america': 690,
#  'sky': 691,
#  'daytime': 692,
#  'gray and white': 693,
#  'palm': 694,
#  'shower': 695,
#  'waves': 696,
#  'happy': 697,
#  'controller': 698,
#  'german': 699,
#  'icing': 700,
#  'smiling': 701,
#  'broccoli': 702,
#  'car': 703,
#  '34': 704,
#  'probably': 705,
#  'not sure': 706,
#  'motorbike': 707,
#  'pole': 708,
#  'catching': 709,
#  'parasailing': 710,
#  'stripes': 711,
#  'gray': 712,
#  'south': 713,
#  'softball': 714,
#  'floor': 715,
#  'rice': 716,
#  'o': 717,
#  'board': 718,
#  'sausage': 719,
#  'wall': 720,
#  'samsung': 721,
#  'wilson': 722,
#  'black and yellow': 723,
#  'few': 724,
#  'behind': 725,
#  'food': 726,
#  'bike': 727,
#  'bull': 728,
#  'lunch': 729,
#  'plants': 730,
#  'tomato': 731,
#  'suit': 732,
#  'yellow and black': 733,
#  'ice cream': 734,
#  '1': 735,
#  'hotel': 736,
#  'nintendo wii': 737,
#  'go': 738,
#  'some': 739,
#  'grapes': 740,
#  'branch': 741,
#  'knife': 742,
#  'real': 743,
#  'bananas': 744,
#  'coffee': 745,
#  'home': 746,
#  'fun': 747,
#  'dining room': 748,
#  'metal': 749,
#  'yes': 750,
#  'surfboards': 751,
#  'bricks': 752,
#  'regular': 753,
#  'gray and black': 754,
#  'fishing': 755,
#  'plate': 756,
#  'beige': 757,
#  'wooden': 758,
#  'apples': 759,
#  'kite': 760,
#  'ketchup': 761,
#  'white and red': 762,
#  'cup': 763,
#  'top': 764,
#  'gas': 765,
#  'towels': 766,
#  'day time': 767,
#  '16': 768,
#  'eggs': 769,
#  'skis': 770,
#  'skating': 771,
#  'train station': 772,
#  'cart': 773,
#  'first': 774,
#  'fur': 775,
#  'resting': 776,
#  'back': 777,
#  'football': 778,
#  '8': 779,
#  'water': 780,
#  'grass': 781,
#  'keyboard': 782,
#  'bird': 783,
#  'india': 784,
#  'pigeon': 785,
#  'backpack': 786,
#  'forward': 787,
#  'brush': 788,
#  'midday': 789,
#  'blonde': 790,
#  'bottom': 791,
#  'sand': 792,
#  'railing': 793,
#  'navy blue': 794,
#  'bench': 795,
#  'very': 796,
#  '45': 797,
#  'sugar': 798,
#  'corner': 799,
#  'zebra': 800,
#  'kiting': 801,
#  'computer': 802,
#  'surfboard': 803,
#  'on beach': 804,
#  'full': 805,
#  'plaid': 806,
#  'pen': 807,
#  'peppers': 808,
#  'meat': 809,
#  'strawberries': 810,
#  'van': 811,
#  'nothing': 812,
#  'white, black': 813,
#  'elephant': 814,
#  'french': 815,
#  'head': 816,
#  'bedroom': 817,
#  'tennis racket': 818,
#  'in grass': 819,
#  'running': 820,
#  'cleaning': 821,
#  'travel': 822,
#  'green and white': 823,
#  '25': 824,
#  'desk': 825,
#  'woman': 826,
#  'teddy bear': 827,
#  'indian': 828,
#  'walk': 829,
#  'tired': 830,
#  'england': 831,
#  'grazing': 832,
#  'wiimote': 833,
#  'on': 834,
#  'giraffes': 835,
#  'english': 836,
#  'dogs': 837,
#  'pepper': 838,
#  'tea': 839,
#  'bikes': 840,
#  'foreground': 841,
#  'rail': 842,
#  'summer': 843,
#  'straight': 844,
#  'japan': 845,
#  'female': 846,
#  'cabinet': 847,
#  'fire hydrant': 848,
#  'on plate': 849,
#  'pie': 850,
#  'large': 851,
#  'blue white': 852,
#  'reading': 853,
#  'spoon': 854,
#  'bowl': 855,
#  'window': 856,
#  'ramp': 857,
#  'a': 858,
#  'on sidewalk': 859,
#  'garbage': 860,
#  'brushing teeth': 861,
#  'on grass': 862,
#  'bus': 863,
#  'dell': 864,
#  'bed': 865,
#  'skate park': 866,
#  'hardwood': 867,
#  'cream': 868,
#  'plain': 869,
#  'moving': 870,
#  'morning': 871,
#  'wii': 872,
#  'fire': 873,
#  'girl': 874,
#  'salad': 875,
#  'basil': 876,
#  'books': 877,
#  'microwave': 878,
#  'fence': 879,
#  'bag': 880,
#  'normal': 881,
#  'tag': 882,
#  'snowboarding': 883,
#  'sandwich': 884,
#  'public': 885,
#  'goggles': 886,
#  'tennis court': 887,
#  'shade': 888,
#  'old': 889,
#  'stop': 890,
#  'sparrow': 891,
#  'plastic': 892,
#  'store': 893,
#  'room': 894,
#  'multi colored': 895,
#  'child': 896,
#  'sidewalk': 897,
#  'pepperoni': 898,
#  'calico': 899,
#  'caucasian': 900,
#  'not': 901,
#  'tracks': 902,
#  'no': 903,
#  'refrigerator': 904,
#  'black': 905,
#  'dinner': 906,
#  'tennis ball': 907,
#  'unknown': 908,
#  'storage': 909,
#  'peach': 910,
#  'playing baseball': 911,
#  'wii controller': 912,
#  'chairs': 913,
#  'nice': 914,
#  'sneakers': 915,
#  'baseball': 916,
#  'chinese': 917,
#  'n/a': 918,
#  'pastry': 919,
#  'cargo': 920,
#  'monitor': 921,
#  'flag': 922,
#  'on counter': 923,
#  'pictures': 924,
#  'boat': 925,
#  'hot dogs': 926,
#  'ground': 927,
#  'photo': 928,
#  'vegetable': 929,
#  'clothing': 930,
#  'flat': 931,
#  'tennis shoes': 932,
#  '10': 933,
#  'checkered': 934,
#  'new york': 935,
#  'day': 936,
#  'little': 937,
#  'shelf': 938,
#  'jeans': 939,
#  'tie': 940,
#  '40': 941,
#  'commercial': 942,
#  'multi-colored': 943,
#  'market': 944,
#  'all': 945,
#  'tall': 946,
#  'adult': 947,
#  'coat': 948,
#  'orange': 949,
#  'clouds': 950,
#  'game controller': 951,
#  'kid': 952,
#  'wine glass': 953,
#  'more than 10': 954,
#  'on wall': 955,
#  'doughnut': 956,
#  'fall': 957,
#  'short': 958,
#  'playing video game': 959,
#  'pink': 960,
#  'roses': 961,
#  '3': 962,
#  'stove': 963,
#  'blue and black': 964,
#  'yellow and blue': 965,
#  'traveling': 966,
#  'iron': 967,
#  'nighttime': 968,
#  'mom': 969,
#  '1 foot': 970,
#  'kite flying': 971,
#  'face': 972,
#  'black and brown': 973,
#  'airport': 974,
#  'baseball cap': 975,
#  'hp': 976,
#  '11': 977,
#  'strawberry': 978,
#  'glass': 979,
#  'brick': 980,
#  'horses': 981,
#  'many': 982,
#  'bicycles': 983,
#  'canada': 984,
#  'oak': 985,
#  'blue and red': 986,
#  'navy': 987,
#  't shirt': 988,
#  'carrot': 989,
#  'cutting': 990,
#  'street sign': 991,
#  'elm': 992,
#  'pot': 993,
#  '9': 994,
#  'business': 995,
#  'nobody': 996}

# %%
NUM_CLASSES = len(id2label)
print("Number of Classes : " , NUM_CLASSES)
# Out:
# Number of Classes :  997

# %% [markdown]
# Testing BERT and ViT

# %%
MAX_LEN = 40

# %%
DEVICE = "cuda"

vit_processor = AutoImageProcessor.from_pretrained("google/vit-base-patch16-224")
# model = AutoModel.from_pretrained("google/vit-base-patch16-224").to(DEVICE)
# vit_model = AutoModel.from_pretrained("google/vit-base-patch16-224")
# Out:
# /home/user/miniconda3/envs/python38/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from transformers import BertTokenizer , BertModel

bert_processor = BertTokenizer.from_pretrained('bert-base-uncased')
# bert_model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# /home/user/miniconda3/envs/python38/lib/python3.8/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# ### TensorFlow

# %% [markdown]
# Create ViT and BERT models

# %%
from transformers import TFAutoModelForSequenceClassification , TFAutoModel , TFAutoModelForImageClassification , TFBertModel
from tensorflow.keras.optimizers import Adam

vit_tf_model = TFAutoModel.from_pretrained("google/vit-base-patch16-224")
bert_tf_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# 2024-05-19 12:47:20.531720: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.555712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.555848: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.556815: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.556915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.557029: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.974765: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.974913: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.975006: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 12:47:20.975080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9912 MB memory:  -> device: 0, name: NVIDIA TITAN V, pci bus id: 0000:02:00.0, compute capability: 7.0
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTModel: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing TFViTModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTModel were not initialized from the PyTorch model and are newly initialized: ['vit.pooler.dense.weight', 'vit.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
class Dataset_Generator(tf.keras.utils.Sequence) :
    def __init__(self, image_filenames, questions , labels, batch_size) :
        self.image_filenames = image_filenames
        self.questions = questions
        self.labels = labels
        self.batch_size = batch_size


    def __len__(self) :
        return int(len(self.image_filenames) / self.batch_size)


    def __getitem__(self, idx) :
        batch_x_img = self.image_filenames[idx * self.batch_size : (idx+1) * self.batch_size]
        batch_x_text = self.questions[idx * self.batch_size : (idx+1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size : (idx+1) * self.batch_size]

        batch_x_img = [Image.open(f"train2014_3d/{i}") for i in batch_x_img]
        
        img_feat = vit_processor(batch_x_img , return_tensors = "np")
        text_feat = bert_processor(batch_x_text , padding='max_length', max_length=MAX_LEN, truncation=True, return_tensors="np")
        
        labels = []
        for i in batch_y:
            r = [0 for i in id2label]
            for t , w in zip(i["ids"] , i["weights"]):
                r[label2id[t]] = w
            labels.append(r)
        
        # return x , y
        # return np.array([
        #         resize(imread('/content/all_images/' + str(file_name)), (80, 80, 3))
        #             for file_name in batch_x])/255.0, np.array(batch_y)
        # print(labels)
        return [img_feat["pixel_values"] , text_feat["input_ids"] , text_feat["attention_mask"]] , np.array(labels)

# %%
BATCH_SIZE = 16

validation_split = 0.3
# validation_split_len = int(validation_split * SAMPLES)

# df_sampled = df.sample(frac=1).reset_index(drop=True) #shuffle the dataset

# df_train = df_sampled[: -validation_split_len]
# df_test = df_sampled[-validation_split_len : - validation_split_len // 2]
# df_val = df_sampled[- validation_split_len // 2 : ]

X = df[["image_id" , "question"]]
Y = df["label"]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=validation_split, random_state=42)

validation_test_split = len(X_test) // 2

training_gen = Dataset_Generator(
    X_train["image_id"].to_list(), 
    X_train["question"].to_list(), 
    y_train.to_list(),
    BATCH_SIZE
)

validation_gen = Dataset_Generator(
    X_test["image_id"][:validation_test_split].to_list(), 
    X_test["question"][:validation_test_split].to_list(), 
    y_test[:validation_test_split].to_list(),
    BATCH_SIZE
)

test_gen = Dataset_Generator(
    X_test["image_id"][validation_test_split:].to_list(), 
    X_test["question"][validation_test_split:].to_list(), 
    y_test[validation_test_split:].to_list(),
    BATCH_SIZE
)

len(X_train) , len(X_test)
# Out:
# (100100, 42900)

# %% [markdown]
# Build our Custom Model

# %%
def build_model():
    vit_inputs = tf.keras.layers.Input(shape=(3, 224, 224))
    vit_tf_model.trainable = True
    x_vit = vit_tf_model(vit_inputs).pooler_output
    
    bert_input1 = tf.keras.layers.Input(shape=(MAX_LEN,) , dtype=tf.int32)
    bert_input2 = tf.keras.layers.Input(shape=(MAX_LEN,) , dtype=tf.int32)
    bert_tf_model.trainable = True
    x_bert = bert_tf_model(input_ids=bert_input1 , attention_mask=bert_input2).pooler_output
    
    # x = np.concatenate([x_vit , x_bert])
    out = tf.keras.layers.Concatenate(axis=1)([x_vit, x_bert])
    # x = x_bert
    
    out = tf.keras.layers.Dense(256 , input_shape=(768*2,) , activation='relu')(out)
    out = tf.keras.layers.BatchNormalization()(out)
    out = tf.keras.layers.Dropout(0.25)(out)
    # out = tf.keras.layers.Dense(512 , input_shape=(768*2,) , activation='relu')(out)
    # out = tf.keras.layers.Dropout(0.25)(out)
    # out = tf.keras.layers.Dense(256 , activation='relu')(out)
    # out = tf.keras.layers.Dropout(0.25)(out)
    out = tf.keras.layers.Dense(64 , activation='relu')(out)
    out = tf.keras.layers.BatchNormalization()(out)
    out = tf.keras.layers.Dropout(0.25)(out)
    out = tf.keras.layers.Dense(NUM_CLASSES , activation='softmax')(out)
    
    # out = tf.keras.layers.Dense(NUM_CLASSES , input_shape=(768*2,) , activation='softmax')(out)
    
    model = tf.keras.models.Model(inputs=[vit_inputs , bert_input1 , bert_input2] , outputs=out)
    
    return model


modelx = build_model()
opt = tf.keras.optimizers.AdamW(3e-5 , 1e-2)
# opt = Adam(3e-5)
modelx.compile(optimizer= opt, loss="categorical_crossentropy", metrics=['accuracy'])
modelx.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 3, 224, 224)]        0         []
#
#  input_2 (InputLayer)        [(None, 40)]                 0         []
#
#  input_3 (InputLayer)        [(None, 40)]                 0         []
#
#  tf_vi_t_model (TFViTModel)  TFBaseModelOutputWithPooli   8638924   ['input_1[0][0]']
#                              ng(last_hidden_state=(None   8
#                              , 197, 768),
#                               pooler_output=(None, 768)
#                              , hidden_states=None, atte
#                              ntions=None)
#
#  tf_bert_model (TFBertModel  TFBaseModelOutputWithPooli   1094822   ['input_2[0][0]',
#  )                           ngAndCrossAttentions(last_   40         'input_3[0][0]']
#                              hidden_state=(None, 40, 76
#                              8),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  concatenate (Concatenate)   (None, 1536)                 0         ['tf_vi_t_model[0][1]',
#                                                                      'tf_bert_model[0][1]']
#
#  dense (Dense)               (None, 256)                  393472    ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 256)                  1024      ['dense[0][0]']
#  Normalization)
#
#  dropout_74 (Dropout)        (None, 256)                  0         ['batch_normalization[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   16448     ['dropout_74[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64)                   256       ['dense_1[0][0]']
#  chNormalization)
#
#  dropout_75 (Dropout)        (None, 64)                   0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 997)                  64805     ['dropout_75[0][0]']
#
# ==================================================================================================
# Total params: 196347493 (749.01 MB)
# Trainable params: 196346853 (749.00 MB)
# Non-trainable params: 640 (2.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Inference

# %%
model_loaded = build_model()
model_loaded.compile(optimizer= opt, loss="categorical_crossentropy", metrics=['accuracy'])
model_loaded.load_weights(f"vqa_{SAMPLE_SET}_clipped.h5")

# %%
model_loaded.evaluate(test_gen)
# Out:
# 2024-05-19 12:49:03.655905: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 1340/1340 [==============================] - 146s 104ms/step - loss: 1.1777 - accuracy: 0.7201
# [1.1776602268218994, 0.7200559973716736]

# %%
from sklearn.metrics import confusion_matrix

#Predict
y_prediction = model_loaded.predict(test_gen)
y_true = test_gen.labels

y_labels = []
for i in y_true:
    r = [0 for i in id2label]
    for t , w in zip(i["ids"] , i["weights"]):
        r[label2id[t]] = w
    y_labels.append(r)
# Out:
# 1340/1340 [==============================] - 140s 103ms/step

# %%
y1 , y2 = np.rint(y_labels[:-10]).astype(np.int32) , np.rint(y_prediction).astype(np.int32)
y1 = y1.argmax(axis=1)
y2 = y2.argmax(axis=1)

y1.shape , y2.shape
# Out:
# ((21440,), (21440,))

# %%
from sklearn.metrics import f1_score, recall_score, accuracy_score , precision_score

f1_score = f1_score(y1 , y2 , average='weighted')
recall_score = recall_score(y1 , y2 , average='weighted')
precision_score = precision_score(y1 , y2 , average='weighted')

print("F1 Score : " , f1_score)
print("Recall : " , recall_score)
print("Precision : " , precision_score)
# Out:
# F1 Score :  0.7009100288460072
# Recall :  0.699580223880597
# Precision :  0.71743627988817
# /home/user/miniconda3/envs/python38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/user/miniconda3/envs/python38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test = df.iloc[22]
# test_question = test["question"]
test_question = "what are the animals eating?"
test_image = Image.open("train2014_3d/" + test["image_id"])

display(test_image)

test_text_feat = bert_processor([test_question] , padding='max_length', max_length=MAX_LEN, truncation=True, return_tensors="np")
test_image_feat = vit_processor([test_image] , return_tensors="np")["pixel_values"]


print("Question : " , test_question)
ans = model_loaded.predict([test_image_feat , test_text_feat["input_ids"] , test_text_feat["attention_mask"]])
ans = np.argmax(ans)
ans = id2label[ans]
print("Answer : " , ans)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x438>
# Question :  what are the animals eating?
# 1/1 [==============================] - 0s 39ms/step
# Answer :  straw
